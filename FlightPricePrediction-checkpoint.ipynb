# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel("All_Flight_Data_Final/All_Flight_Data_Final.xlsx")
data.head(10)
# Out:
#   flight_name       date departure_time departure_loc flight_duration  \
# 0      Indigo 2023-04-01       23:00:00     Bangalore         01h 05m
# 1     Vistara 2023-04-01       21:25:00     Bangalore         01h 05m
# 2     AirAsia 2023-04-01       13:20:00     Bangalore         01h 15m
# 3     Vistara 2023-04-01       18:30:00     Bangalore         01h 10m
# 4      Indigo 2023-04-01       22:00:00     Bangalore         01h 05m
# 5     AirAsia 2023-04-01       15:40:00     Bangalore         01h 10m
# 6    AkasaAir 2023-04-01       18:25:00     Bangalore         01h 10m
# 7     AirAsia 2023-04-01       14:05:00     Bangalore         01h 10m
# 8      Indigo 2023-04-01       20:00:00     Bangalore         01h 05m
# 9      Indigo 2023-04-01       23:50:00     Bangalore         06h 20m
#
#        stops arrival_time arrival_loc  price
# 0  non-stop      00:05:00   Hyderabad   2468
# 1  non-stop      22:30:00   Hyderabad   2652
# 2  non-stop      14:35:00   Hyderabad   2954
# 3  non-stop      19:40:00   Hyderabad   2862
# 4  non-stop      23:05:00   Hyderabad   2954
# 5  non-stop      16:50:00   Hyderabad   3254
# 6  non-stop      19:35:00   Hyderabad   2741
# 7  non-stop      15:15:00   Hyderabad   3954
# 8  non-stop      21:05:00   Hyderabad   3771
# 9     1-stop     06:10:00   Hyderabad   4209

# %%
data.isnull().sum()
# Out:
# flight_name        0
# date               0
# departure_time     0
# departure_loc      0
# flight_duration    0
# stops              0
# arrival_time       0
# arrival_loc        0
# price              0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 320787 entries, 0 to 320786
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   flight_name      320787 non-null  object
#  1   date             320787 non-null  datetime64[ns]
#  2   departure_time   320787 non-null  object
#  3   departure_loc    320787 non-null  object
#  4   flight_duration  320787 non-null  object
#  5   stops            320787 non-null  object
#  6   arrival_time     320787 non-null  object
#  7   arrival_loc      320787 non-null  object
#  8   price            320787 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(7)
# memory usage: 22.0+ MB

# %%
# Distribution of Prices

data['price'].hist()
# Out:
# <Axes: >

# %%
# Airline vs Price

sns.catplot(y = 'price', x = 'flight_name', data = data.sort_values('price', ascending=False),kind='boxen',height = 6, aspect = 3)
plt.xlabel('Airline',size=15)
plt.ylabel('Price',size=15)
plt.show()

# %%
data['dep_hour'] = pd.to_datetime(data['departure_time'].astype(str)).dt.hour
data['dep_min'] = pd.to_datetime(data['departure_time'].astype(str)).dt.minute
data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\851089227.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['dep_hour'] = pd.to_datetime(data['departure_time'].astype(str)).dt.hour
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\851089227.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['dep_min'] = pd.to_datetime(data['departure_time'].astype(str)).dt.minute
#        flight_name       date departure_time departure_loc flight_duration  \
# 0           Indigo 2023-04-01       23:00:00     Bangalore         01h 05m
# 1          Vistara 2023-04-01       21:25:00     Bangalore         01h 05m
# 2          AirAsia 2023-04-01       13:20:00     Bangalore         01h 15m
# 3          Vistara 2023-04-01       18:30:00     Bangalore         01h 10m
# 4           Indigo 2023-04-01       22:00:00     Bangalore         01h 05m
# ...            ...        ...            ...           ...             ...
# 320782    GO FIRST 2023-05-31       05:20:00         Delhi         13h 05m
# 320783   Air India 2023-05-31       10:15:00         Delhi         05h 25m
# 320784    GO FIRST 2023-05-31       11:50:00         Delhi         06h 35m
# 320785    GO FIRST 2023-05-31       05:20:00         Delhi         06h 10m
# 320786    GO FIRST 2023-05-31       09:25:00         Delhi         09h 00m
#
#             stops arrival_time arrival_loc  price  dep_hour  dep_min
# 0       non-stop      00:05:00   Hyderabad   2468        23        0
# 1       non-stop      22:30:00   Hyderabad   2652        21       25
# 2       non-stop      14:35:00   Hyderabad   2954        13       20
# 3       non-stop      19:40:00   Hyderabad   2862        18       30
# 4       non-stop      23:05:00   Hyderabad   2954        22        0
# ...           ...          ...         ...    ...       ...      ...
# 320782     1-stop     18:25:00      Mumbai  20394         5       20
# 320783     1-stop     15:40:00      Mumbai  20130        10       15
# 320784     1-stop     18:25:00      Mumbai  25922        11       50
# 320785     1-stop     11:30:00      Mumbai  26130         5       20
# 320786     1-stop     18:25:00      Mumbai  26757         9       25
#
# [320787 rows x 11 columns]

# %%
data['arr_hour'] = pd.to_datetime(data['arrival_time'].astype(str)).dt.hour
data['arr_min'] = pd.to_datetime(data['arrival_time'].astype(str)).dt.minute
data
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\3580146416.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['arr_hour'] = pd.to_datetime(data['arrival_time'].astype(str)).dt.hour
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\3580146416.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['arr_min'] = pd.to_datetime(data['arrival_time'].astype(str)).dt.minute
#        flight_name       date departure_time departure_loc flight_duration  \
# 0           Indigo 2023-04-01       23:00:00     Bangalore         01h 05m
# 1          Vistara 2023-04-01       21:25:00     Bangalore         01h 05m
# 2          AirAsia 2023-04-01       13:20:00     Bangalore         01h 15m
# 3          Vistara 2023-04-01       18:30:00     Bangalore         01h 10m
# 4           Indigo 2023-04-01       22:00:00     Bangalore         01h 05m
# ...            ...        ...            ...           ...             ...
# 320782    GO FIRST 2023-05-31       05:20:00         Delhi         13h 05m
# 320783   Air India 2023-05-31       10:15:00         Delhi         05h 25m
# 320784    GO FIRST 2023-05-31       11:50:00         Delhi         06h 35m
# 320785    GO FIRST 2023-05-31       05:20:00         Delhi         06h 10m
# 320786    GO FIRST 2023-05-31       09:25:00         Delhi         09h 00m
#
#             stops arrival_time arrival_loc  price  dep_hour  dep_min  \
# 0       non-stop      00:05:00   Hyderabad   2468        23        0
# 1       non-stop      22:30:00   Hyderabad   2652        21       25
# 2       non-stop      14:35:00   Hyderabad   2954        13       20
# 3       non-stop      19:40:00   Hyderabad   2862        18       30
# 4       non-stop      23:05:00   Hyderabad   2954        22        0
# ...           ...          ...         ...    ...       ...      ...
# 320782     1-stop     18:25:00      Mumbai  20394         5       20
# 320783     1-stop     15:40:00      Mumbai  20130        10       15
# 320784     1-stop     18:25:00      Mumbai  25922        11       50
# 320785     1-stop     11:30:00      Mumbai  26130         5       20
# 320786     1-stop     18:25:00      Mumbai  26757         9       25
#
#         arr_hour  arr_min
# 0              0        5
# 1             22       30
# 2             14       35
# 3             19       40
# 4             23        5
# ...          ...      ...
# 320782        18       25
# 320783        15       40
# 320784        18       25
# 320785        11       30
# 320786        18       25
#
# [320787 rows x 13 columns]

# %%
data['Journey_Day'] = pd.to_datetime(data['date']).dt.day
data['Journey_Month'] = pd.to_datetime(data['date']).dt.month
data
# Out:
#        flight_name       date departure_time departure_loc flight_duration  \
# 0           Indigo 2023-04-01       23:00:00     Bangalore         01h 05m
# 1          Vistara 2023-04-01       21:25:00     Bangalore         01h 05m
# 2          AirAsia 2023-04-01       13:20:00     Bangalore         01h 15m
# 3          Vistara 2023-04-01       18:30:00     Bangalore         01h 10m
# 4           Indigo 2023-04-01       22:00:00     Bangalore         01h 05m
# ...            ...        ...            ...           ...             ...
# 320782    GO FIRST 2023-05-31       05:20:00         Delhi         13h 05m
# 320783   Air India 2023-05-31       10:15:00         Delhi         05h 25m
# 320784    GO FIRST 2023-05-31       11:50:00         Delhi         06h 35m
# 320785    GO FIRST 2023-05-31       05:20:00         Delhi         06h 10m
# 320786    GO FIRST 2023-05-31       09:25:00         Delhi         09h 00m
#
#             stops arrival_time arrival_loc  price  dep_hour  dep_min  \
# 0       non-stop      00:05:00   Hyderabad   2468        23        0
# 1       non-stop      22:30:00   Hyderabad   2652        21       25
# 2       non-stop      14:35:00   Hyderabad   2954        13       20
# 3       non-stop      19:40:00   Hyderabad   2862        18       30
# 4       non-stop      23:05:00   Hyderabad   2954        22        0
# ...           ...          ...         ...    ...       ...      ...
# 320782     1-stop     18:25:00      Mumbai  20394         5       20
# 320783     1-stop     15:40:00      Mumbai  20130        10       15
# 320784     1-stop     18:25:00      Mumbai  25922        11       50
# 320785     1-stop     11:30:00      Mumbai  26130         5       20
# 320786     1-stop     18:25:00      Mumbai  26757         9       25
#
#         arr_hour  arr_min  Journey_Day  Journey_Month
# 0              0        5            1              4
# 1             22       30            1              4
# 2             14       35            1              4
# 3             19       40            1              4
# 4             23        5            1              4
# ...          ...      ...          ...            ...
# 320782        18       25           31              5
# 320783        15       40           31              5
# 320784        18       25           31              5
# 320785        11       30           31              5
# 320786        18       25           31              5
#
# [320787 rows x 15 columns]

# %%
data.drop(['date','departure_time','arrival_time'], axis = 1, inplace = True)
data
# Out:
#        flight_name departure_loc flight_duration      stops arrival_loc  \
# 0           Indigo     Bangalore         01h 05m  non-stop    Hyderabad
# 1          Vistara     Bangalore         01h 05m  non-stop    Hyderabad
# 2          AirAsia     Bangalore         01h 15m  non-stop    Hyderabad
# 3          Vistara     Bangalore         01h 10m  non-stop    Hyderabad
# 4           Indigo     Bangalore         01h 05m  non-stop    Hyderabad
# ...            ...           ...             ...        ...         ...
# 320782    GO FIRST         Delhi         13h 05m     1-stop      Mumbai
# 320783   Air India         Delhi         05h 25m     1-stop      Mumbai
# 320784    GO FIRST         Delhi         06h 35m     1-stop      Mumbai
# 320785    GO FIRST         Delhi         06h 10m     1-stop      Mumbai
# 320786    GO FIRST         Delhi         09h 00m     1-stop      Mumbai
#
#         price  dep_hour  dep_min  arr_hour  arr_min  Journey_Day  \
# 0        2468        23        0         0        5            1
# 1        2652        21       25        22       30            1
# 2        2954        13       20        14       35            1
# 3        2862        18       30        19       40            1
# 4        2954        22        0        23        5            1
# ...       ...       ...      ...       ...      ...          ...
# 320782  20394         5       20        18       25           31
# 320783  20130        10       15        15       40           31
# 320784  25922        11       50        18       25           31
# 320785  26130         5       20        11       30           31
# 320786  26757         9       25        18       25           31
#
#         Journey_Month
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   4
# ...               ...
# 320782              5
# 320783              5
# 320784              5
# 320785              5
# 320786              5
#
# [320787 rows x 12 columns]

# %%
data['stops'].value_counts()
# Out:
# stops
# 1-stop                243935
# non-stop               58830
# 2+-stop                16392
# 1-stopVia Indore         638
# 1-stopVia IDR            582
# 1-stopVia Mumbai         151
# 1-stopVia VTZ            108
# 1-stopVia Delhi          105
# 1-stopVia Bagdogra        46
# Name: count, dtype: int64

# %%
data.replace({'non-stop ' : 0, '1-stop' : 1, '1-stopVia Indore' : 1,'1-stopVia Mumbai' : 1, '2+-stop' : 2,'1-stopVia IDR' : 1,'1-stopVia VTZ' : 1,'1-stopVia Delhi' : 1,'1-stopVia Bagdogra' : 1}, inplace=True)
data
# Out:
#        flight_name departure_loc flight_duration  stops arrival_loc  price  \
# 0           Indigo     Bangalore         01h 05m      0   Hyderabad   2468
# 1          Vistara     Bangalore         01h 05m      0   Hyderabad   2652
# 2          AirAsia     Bangalore         01h 15m      0   Hyderabad   2954
# 3          Vistara     Bangalore         01h 10m      0   Hyderabad   2862
# 4           Indigo     Bangalore         01h 05m      0   Hyderabad   2954
# ...            ...           ...             ...    ...         ...    ...
# 320782    GO FIRST         Delhi         13h 05m      1      Mumbai  20394
# 320783   Air India         Delhi         05h 25m      1      Mumbai  20130
# 320784    GO FIRST         Delhi         06h 35m      1      Mumbai  25922
# 320785    GO FIRST         Delhi         06h 10m      1      Mumbai  26130
# 320786    GO FIRST         Delhi         09h 00m      1      Mumbai  26757
#
#         dep_hour  dep_min  arr_hour  arr_min  Journey_Day  Journey_Month
# 0             23        0         0        5            1              4
# 1             21       25        22       30            1              4
# 2             13       20        14       35            1              4
# 3             18       30        19       40            1              4
# 4             22        0        23        5            1              4
# ...          ...      ...       ...      ...          ...            ...
# 320782         5       20        18       25           31              5
# 320783        10       15        15       40           31              5
# 320784        11       50        18       25           31              5
# 320785         5       20        11       30           31              5
# 320786         9       25        18       25           31              5
#
# [320787 rows x 12 columns]

# %%
data['stops'].value_counts()
# Out:
# stops
# 1    245565
# 0     58830
# 2     16392
# Name: count, dtype: int64

# %%
duration = list(data['flight_duration'])

for i in range(len(duration)):
    if len(duration[i].split()) != 2:
        if "h" in duration[i]:
            duration[i] = duration[i].strip() + " 0m"
        else:
            duration[i] = "0h " + duration[i]
            
duration_hours = []
duration_mins = []
for i in range(len(duration)):
    duration_hours.append(int(duration[i].split(sep = "h")[0]))
    duration_mins.append(int(duration[i].split(sep = "m")[0].split()[-1]))

# %%
data['Duration_hours'] = duration_hours
data['Duration_mins'] = duration_mins
data
# Out:
#        flight_name departure_loc flight_duration  stops arrival_loc  price  \
# 0           Indigo     Bangalore         01h 05m      0   Hyderabad   2468
# 1          Vistara     Bangalore         01h 05m      0   Hyderabad   2652
# 2          AirAsia     Bangalore         01h 15m      0   Hyderabad   2954
# 3          Vistara     Bangalore         01h 10m      0   Hyderabad   2862
# 4           Indigo     Bangalore         01h 05m      0   Hyderabad   2954
# ...            ...           ...             ...    ...         ...    ...
# 320782    GO FIRST         Delhi         13h 05m      1      Mumbai  20394
# 320783   Air India         Delhi         05h 25m      1      Mumbai  20130
# 320784    GO FIRST         Delhi         06h 35m      1      Mumbai  25922
# 320785    GO FIRST         Delhi         06h 10m      1      Mumbai  26130
# 320786    GO FIRST         Delhi         09h 00m      1      Mumbai  26757
#
#         dep_hour  dep_min  arr_hour  arr_min  Journey_Day  Journey_Month  \
# 0             23        0         0        5            1              4
# 1             21       25        22       30            1              4
# 2             13       20        14       35            1              4
# 3             18       30        19       40            1              4
# 4             22        0        23        5            1              4
# ...          ...      ...       ...      ...          ...            ...
# 320782         5       20        18       25           31              5
# 320783        10       15        15       40           31              5
# 320784        11       50        18       25           31              5
# 320785         5       20        11       30           31              5
# 320786         9       25        18       25           31              5
#
#         Duration_hours  Duration_mins
# 0                    1              5
# 1                    1              5
# 2                    1             15
# 3                    1             10
# 4                    1              5
# ...                ...            ...
# 320782              13              5
# 320783               5             25
# 320784               6             35
# 320785               6             10
# 320786               9              0
#
# [320787 rows x 14 columns]

# %%
data.drop(['flight_duration'],axis=1,inplace=True)
data
# Out:
#        flight_name departure_loc  stops arrival_loc  price  dep_hour  dep_min  \
# 0           Indigo     Bangalore      0   Hyderabad   2468        23        0
# 1          Vistara     Bangalore      0   Hyderabad   2652        21       25
# 2          AirAsia     Bangalore      0   Hyderabad   2954        13       20
# 3          Vistara     Bangalore      0   Hyderabad   2862        18       30
# 4           Indigo     Bangalore      0   Hyderabad   2954        22        0
# ...            ...           ...    ...         ...    ...       ...      ...
# 320782    GO FIRST         Delhi      1      Mumbai  20394         5       20
# 320783   Air India         Delhi      1      Mumbai  20130        10       15
# 320784    GO FIRST         Delhi      1      Mumbai  25922        11       50
# 320785    GO FIRST         Delhi      1      Mumbai  26130         5       20
# 320786    GO FIRST         Delhi      1      Mumbai  26757         9       25
#
#         arr_hour  arr_min  Journey_Day  Journey_Month  Duration_hours  \
# 0              0        5            1              4               1
# 1             22       30            1              4               1
# 2             14       35            1              4               1
# 3             19       40            1              4               1
# 4             23        5            1              4               1
# ...          ...      ...          ...            ...             ...
# 320782        18       25           31              5              13
# 320783        15       40           31              5               5
# 320784        18       25           31              5               6
# 320785        11       30           31              5               6
# 320786        18       25           31              5               9
#
#         Duration_mins
# 0                   5
# 1                   5
# 2                  15
# 3                  10
# 4                   5
# ...               ...
# 320782              5
# 320783             25
# 320784             35
# 320785             10
# 320786              0
#
# [320787 rows x 13 columns]

# %%
data['flight_name'].value_counts()
# Out:
# flight_name
# Vistara        94901
# Air India      93839
# Indigo         82660
# AirAsia        20607
# GO FIRST       17395
# SpiceJet        6652
# AkasaAir        4046
# AllianceAir      622
# StarAir           65
# Name: count, dtype: int64

# %%
Airline = data['flight_name']
Airline = pd.get_dummies(Airline, drop_first=True)
Airline.head()
# Out:
#    AirAsia  AkasaAir  AllianceAir  GO FIRST  Indigo  SpiceJet  StarAir  \
# 0    False     False        False     False    True     False    False
# 1    False     False        False     False   False     False    False
# 2     True     False        False     False   False     False    False
# 3    False     False        False     False   False     False    False
# 4    False     False        False     False    True     False    False
#
#    Vistara
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False

# %%
list1 = ['departure_loc', 'arrival_loc']
for l in list1:
    print(data[[l]].value_counts(), '\n')
# Out:
# departure_loc
# Bangalore        99284
# Delhi            79409
# Mumbai           72637
# Chennai          69457
# Name: count, dtype: int64
#
# arrival_loc
# Mumbai         82200
# Delhi          80711
# Kolkata        77496
# Hyderabad      57836
# Bangalore      22544
# Name: count, dtype: int64

# %%
data = pd.get_dummies(data = data, columns=list1, drop_first=True)
data
# Out:
#        flight_name  stops  price  dep_hour  dep_min  arr_hour  arr_min  \
# 0           Indigo      0   2468        23        0         0        5
# 1          Vistara      0   2652        21       25        22       30
# 2          AirAsia      0   2954        13       20        14       35
# 3          Vistara      0   2862        18       30        19       40
# 4           Indigo      0   2954        22        0        23        5
# ...            ...    ...    ...       ...      ...       ...      ...
# 320782    GO FIRST      1  20394         5       20        18       25
# 320783   Air India      1  20130        10       15        15       40
# 320784    GO FIRST      1  25922        11       50        18       25
# 320785    GO FIRST      1  26130         5       20        11       30
# 320786    GO FIRST      1  26757         9       25        18       25
#
#         Journey_Day  Journey_Month  Duration_hours  Duration_mins  \
# 0                 1              4               1              5
# 1                 1              4               1              5
# 2                 1              4               1             15
# 3                 1              4               1             10
# 4                 1              4               1              5
# ...             ...            ...             ...            ...
# 320782           31              5              13              5
# 320783           31              5               5             25
# 320784           31              5               6             35
# 320785           31              5               6             10
# 320786           31              5               9              0
#
#         departure_loc_Chennai  departure_loc_Delhi  departure_loc_Mumbai  \
# 0                       False                False                 False
# 1                       False                False                 False
# 2                       False                False                 False
# 3                       False                False                 False
# 4                       False                False                 False
# ...                       ...                  ...                   ...
# 320782                  False                 True                 False
# 320783                  False                 True                 False
# 320784                  False                 True                 False
# 320785                  False                 True                 False
# 320786                  False                 True                 False
#
#         arrival_loc_Delhi  arrival_loc_Hyderabad  arrival_loc_Kolkata  \
# 0                   False                   True                False
# 1                   False                   True                False
# 2                   False                   True                False
# 3                   False                   True                False
# 4                   False                   True                False
# ...                   ...                    ...                  ...
# 320782              False                  False                False
# 320783              False                  False                False
# 320784              False                  False                False
# 320785              False                  False                False
# 320786              False                  False                False
#
#         arrival_loc_Mumbai
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 320782                True
# 320783                True
# 320784                True
# 320785                True
# 320786                True
#
# [320787 rows x 18 columns]

# %%
data = pd.concat([data, Airline], axis = 1)
data
# Out:
#        flight_name  stops  price  dep_hour  dep_min  arr_hour  arr_min  \
# 0           Indigo      0   2468        23        0         0        5
# 1          Vistara      0   2652        21       25        22       30
# 2          AirAsia      0   2954        13       20        14       35
# 3          Vistara      0   2862        18       30        19       40
# 4           Indigo      0   2954        22        0        23        5
# ...            ...    ...    ...       ...      ...       ...      ...
# 320782    GO FIRST      1  20394         5       20        18       25
# 320783   Air India      1  20130        10       15        15       40
# 320784    GO FIRST      1  25922        11       50        18       25
# 320785    GO FIRST      1  26130         5       20        11       30
# 320786    GO FIRST      1  26757         9       25        18       25
#
#         Journey_Day  Journey_Month  Duration_hours  ...  arrival_loc_Kolkata  \
# 0                 1              4               1  ...                False
# 1                 1              4               1  ...                False
# 2                 1              4               1  ...                False
# 3                 1              4               1  ...                False
# 4                 1              4               1  ...                False
# ...             ...            ...             ...  ...                  ...
# 320782           31              5              13  ...                False
# 320783           31              5               5  ...                False
# 320784           31              5               6  ...                False
# 320785           31              5               6  ...                False
# 320786           31              5               9  ...                False
#
#         arrival_loc_Mumbai  AirAsia  AkasaAir  AllianceAir  GO FIRST  Indigo  \
# 0                    False    False     False        False     False    True
# 1                    False    False     False        False     False   False
# 2                    False     True     False        False     False   False
# 3                    False    False     False        False     False   False
# 4                    False    False     False        False     False    True
# ...                    ...      ...       ...          ...       ...     ...
# 320782                True    False     False        False      True   False
# 320783                True    False     False        False     False   False
# 320784                True    False     False        False      True   False
# 320785                True    False     False        False      True   False
# 320786                True    False     False        False      True   False
#
#         SpiceJet  StarAir  Vistara
# 0          False    False    False
# 1          False    False     True
# 2          False    False    False
# 3          False    False     True
# 4          False    False    False
# ...          ...      ...      ...
# 320782     False    False    False
# 320783     False    False    False
# 320784     False    False    False
# 320785     False    False    False
# 320786     False    False    False
#
# [320787 rows x 26 columns]

# %%
data.drop(['flight_name'],axis=1,inplace=True)
data
# Out:
#         stops  price  dep_hour  dep_min  arr_hour  arr_min  Journey_Day  \
# 0           0   2468        23        0         0        5            1
# 1           0   2652        21       25        22       30            1
# 2           0   2954        13       20        14       35            1
# 3           0   2862        18       30        19       40            1
# 4           0   2954        22        0        23        5            1
# ...       ...    ...       ...      ...       ...      ...          ...
# 320782      1  20394         5       20        18       25           31
# 320783      1  20130        10       15        15       40           31
# 320784      1  25922        11       50        18       25           31
# 320785      1  26130         5       20        11       30           31
# 320786      1  26757         9       25        18       25           31
#
#         Journey_Month  Duration_hours  Duration_mins  ...  \
# 0                   4               1              5  ...
# 1                   4               1              5  ...
# 2                   4               1             15  ...
# 3                   4               1             10  ...
# 4                   4               1              5  ...
# ...               ...             ...            ...  ...
# 320782              5              13              5  ...
# 320783              5               5             25  ...
# 320784              5               6             35  ...
# 320785              5               6             10  ...
# 320786              5               9              0  ...
#
#         arrival_loc_Kolkata  arrival_loc_Mumbai  AirAsia  AkasaAir  \
# 0                     False               False    False     False
# 1                     False               False    False     False
# 2                     False               False     True     False
# 3                     False               False    False     False
# 4                     False               False    False     False
# ...                     ...                 ...      ...       ...
# 320782                False                True    False     False
# 320783                False                True    False     False
# 320784                False                True    False     False
# 320785                False                True    False     False
# 320786                False                True    False     False
#
#         AllianceAir  GO FIRST  Indigo  SpiceJet  StarAir  Vistara
# 0             False     False    True     False    False    False
# 1             False     False   False     False    False     True
# 2             False     False   False     False    False    False
# 3             False     False   False     False    False     True
# 4             False     False    True     False    False    False
# ...             ...       ...     ...       ...      ...      ...
# 320782        False      True   False     False    False    False
# 320783        False     False   False     False    False    False
# 320784        False      True   False     False    False    False
# 320785        False      True   False     False    False    False
# 320786        False      True   False     False    False    False
#
# [320787 rows x 25 columns]

# %%
data.shape
# Out:
# (320787, 25)

# %%
data.columns
# Out:
# Index(['stops', 'price', 'dep_hour', 'dep_min', 'arr_hour', 'arr_min',
#        'Journey_Day', 'Journey_Month', 'Duration_hours', 'Duration_mins',
#        'departure_loc_Chennai', 'departure_loc_Delhi', 'departure_loc_Mumbai',
#        'arrival_loc_Delhi', 'arrival_loc_Hyderabad', 'arrival_loc_Kolkata',
#        'arrival_loc_Mumbai', 'AirAsia', 'AkasaAir', 'AllianceAir', 'GO FIRST',
#        'Indigo', 'SpiceJet', 'StarAir', 'Vistara'],
#       dtype='object')

# %%
X = data.loc[:, ['stops', 'dep_hour', 'dep_min', 'arr_hour', 'arr_min',
       'Journey_Day', 'Journey_Month', 'Duration_hours', 'Duration_mins',
       'departure_loc_Chennai', 'departure_loc_Delhi', 'departure_loc_Mumbai',
       'arrival_loc_Delhi', 'arrival_loc_Hyderabad', 'arrival_loc_Kolkata',
       'arrival_loc_Mumbai', 'AirAsia', 'AkasaAir', 'AllianceAir', 'GO FIRST',
       'Indigo', 'SpiceJet', 'StarAir', 'Vistara']]
X.head()
# Out:
#    stops  dep_hour  dep_min  arr_hour  arr_min  Journey_Day  Journey_Month  \
# 0      0        23        0         0        5            1              4
# 1      0        21       25        22       30            1              4
# 2      0        13       20        14       35            1              4
# 3      0        18       30        19       40            1              4
# 4      0        22        0        23        5            1              4
#
#    Duration_hours  Duration_mins  departure_loc_Chennai  ...  \
# 0               1              5                  False  ...
# 1               1              5                  False  ...
# 2               1             15                  False  ...
# 3               1             10                  False  ...
# 4               1              5                  False  ...
#
#    arrival_loc_Kolkata  arrival_loc_Mumbai  AirAsia  AkasaAir  AllianceAir  \
# 0                False               False    False     False        False
# 1                False               False    False     False        False
# 2                False               False     True     False        False
# 3                False               False    False     False        False
# 4                False               False    False     False        False
#
#    GO FIRST  Indigo  SpiceJet  StarAir  Vistara
# 0     False    True     False    False    False
# 1     False   False     False    False     True
# 2     False   False     False    False    False
# 3     False   False     False    False     True
# 4     False    True     False    False    False
#
# [5 rows x 24 columns]

# %%
y = data.iloc[:, 1]
y.head()
# Out:
# 0    2468
# 1    2652
# 2    2954
# 3    2862
# 4    2954
# Name: price, dtype: int64

# %%
plt.figure(figsize = (18, 18))
sns.heatmap(data.corr(),annot = True, cmap = 'RdYlGn')

plt.show()

# %% [markdown]
# ## Extra TreeRegressor

# %%
from sklearn.ensemble import ExtraTreesRegressor

selection = ExtraTreesRegressor()
selection.fit(X, y)
# Out:
# ExtraTreesRegressor()

# %%
print(selection.feature_importances_)
# Out:
# [1.62980466e-01 3.89790161e-02 3.91120949e-02 5.61441243e-02
#  7.17267784e-02 1.03496269e-01 6.32310822e-02 5.96420265e-02
#  3.01865790e-02 3.35212488e-02 2.48169714e-02 1.24793311e-02
#  1.67285036e-02 1.28375443e-02 4.53767388e-02 5.54622948e-02
#  3.67537479e-02 1.48479076e-03 2.63188928e-04 7.06233167e-03
#  9.76494729e-02 7.71820001e-03 5.99607666e-06 2.23412023e-02]

# %%
# Feature Importances

plt.figure(figsize = (12, 8))
feat_importances = pd.Series(selection.feature_importances_, index=X.columns)
feat_importances.nlargest(30).plot(kind='barh')
plt.show()

# %%
x = data.drop(['price'],axis=1)
y = data['price']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data1 = scaler.fit_transform(x)

data1[0]
# Out:
# array([-1.86274129,  1.81888779, -1.37475062, -2.18717816, -1.24924544,
#        -1.71126742, -1.40884268, -1.27206631, -1.25534566, -0.52569742,
#        -0.57356946, -0.54103058, -0.5798184 ,  2.13225081, -0.56438651,
#        -0.58696543, -0.26200918, -0.11302143, -0.04407662, -0.23944742,
#         1.69729222, -0.14551842, -0.01423614, -0.6481727 ])

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=123)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((288708, 24), (32079, 24), (288708,), (32079,))

# %% [markdown]
# ## ExtraTreesRegressor Model

# %%
selection = ExtraTreesRegressor()
selection.fit(x_train, y_train)
# Out:
# ExtraTreesRegressor()

# %%
from sklearn.metrics import mean_squared_error, r2_score

def metrics(y_true, y_pred):
    print(f'RMSE:', mean_squared_error(y_true, y_pred) ** 0.5)
    print(f'R_Squared_Value:', r2_score(y_true, y_pred))
    
def accuracy(y_true, y_pred):
    errors = abs(y_true - y_pred)
    mape = 100 * np.mean(errors/y_true)
    accuracy = 100 - mape
    return accuracy

# %%
y_pred = selection.predict(x_test)

# %%
metrics(y_test, y_pred)
# Out:
# RMSE: 1445.6797629131684
# R_Squared_Value: 0.906236474238823

# %%
accuracy(y_test, y_pred)
# Out:
# 94.21951715217402

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

def metrics(y_true, y_pred):
    print(f'RMSE:', mean_squared_error(y_true, y_pred) ** 0.5)
    print(f'R_Squared_Value:', r2_score(y_true, y_pred))
    
def accuracy(y_true, y_pred):
    errors = abs(y_true - y_pred)
    mape = 100 * np.mean(errors/y_true)
    accuracy = 100 - mape
    return accuracy

# %%
y_pred = model.predict(x_test)

# %%
metrics(y_test, y_pred)
# Out:
# RMSE: 3765.448082358372
# R_Squared_Value: 0.36390342931968334

# %%
accuracy(y_test, y_pred)
# Out:
# 72.25089165756367

# %%
sns.distplot(y_test-y_pred)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\3453123835.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-y_pred)

# %% [markdown]
# ## XGBoost Model

# %%
import xgboost as xg

# %%
xgb_r = xg.XGBRegressor(objective ='reg:linear',n_estimators = 10, seed = 123)

# %%
xgb_r.fit(x_train, y_train)
# Out:
# [11:46:37] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=10, n_jobs=0,
#              num_parallel_tree=1, objective='reg:linear', predictor='auto',
#              random_state=123, reg_alpha=0, ...)

# %%
pred = xgb_r.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error as MSE

# %%
metrics(y_test, pred)
# Out:
# RMSE: 2946.8091509201977
# R_Squared_Value: 0.6104226079747694

# %%
accuracy(y_test, pred)
# Out:
# 82.08975983206507

# %%
sns.distplot(y_test-pred)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\3860349970.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-pred)

# %% [markdown]
# ## Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor

model_random_forest = RandomForestRegressor(n_estimators = 100, min_samples_split=3)
model_random_forest.fit(x_train, y_train)
# Out:
# RandomForestRegressor(min_samples_split=3)

# %%
pred_rf = model_random_forest.predict(x_test)

# %%
metrics(y_test, pred_rf)
# Out:
# RMSE: 1358.7112709394823
# R_Squared_Value: 0.9171783111100789

# %%
accuracy(y_test, pred_rf)
# Out:
# 94.24905916122418

# %%
sns.distplot(y_test-pred)
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\3860349970.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-pred)

# %%
plt.scatter(y_test, y_pred, alpha = 0.5)
plt.show()

# %%
t_data= pd.read_csv('Unseen_data.csv')
t_data.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways      27/05/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo       6/03/2019     Delhi      Cochin  DEL → MAA → COK
# 2          Air India      21/03/2019     Delhi      Cochin  DEL → BLR → COK
# 3            Vistara      18/03/2019  Banglore   New Delhi        BLR → DEL
# 4  Multiple carriers      27/05/2019     Delhi      Cochin  DEL → BOM → COK
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    07:05         19:00  11h 55m      1 stop  In-flight meal not included
# 1    02:05         07:25   5h 20m      1 stop                      No info
# 2    09:45         23:00  13h 15m      1 stop                      No info
# 3    21:10  00:05 16 Mar   2h 55m    non-stop                      No info
# 4    08:30         19:15  10h 45m      1 stop                      No info
#
#    Price
# 0  12898
# 1  10851
# 2   5704
# 3  11598
# 4   9149

# %%
t_data['dep_hour'] = pd.to_datetime(t_data['Dep_Time'].astype(str)).dt.hour
t_data['dep_min'] = pd.to_datetime(t_data['Dep_Time'].astype(str)).dt.minute

t_data['arr_hour'] = pd.to_datetime(t_data['Arrival_Time'].astype(str)).dt.hour
t_data['arr_min'] = pd.to_datetime(t_data['Arrival_Time'].astype(str)).dt.minute

t_data['Journey_Day'] = pd.to_datetime(t_data['Date_of_Journey']).dt.day
t_data['Journey_Month'] = pd.to_datetime(t_data['Date_of_Journey']).dt.month

t_data.drop(['Date_of_Journey','Dep_Time','Arrival_Time'], axis = 1, inplace = True)

t_data['Total_Stops'].value_counts()
t_data.replace({'non-stop':0,'1 stop':1,'2 stops':2,'3 stops':3,'4 stops':4}, inplace=True)

duration = list(t_data['Duration'])

for i in range(len(duration)):
    if len(duration[i].split()) != 2:
        if "h" in duration[i]:
            duration[i] = duration[i].strip() + " 0m"
        else:
            duration[i] = "0h " + duration[i]
            
duration_hours = []
duration_mins = []
for i in range(len(duration)):
    duration_hours.append(int(duration[i].split(sep = "h")[0]))
    duration_mins.append(int(duration[i].split(sep = "m")[0].split()[-1]))

t_data['Duration_hours'] = duration_hours
t_data['Duration_mins'] = duration_mins

t_data.drop(['Duration'],axis=1,inplace=True)

Airline = t_data['Airline']
Airline = pd.get_dummies(Airline, drop_first=True)

list2 = ['Source', 'Destination']
t_data = pd.get_dummies(data = t_data, columns=list2, drop_first=True)
t_data = pd.concat([t_data, Airline], axis = 1)
t_data.drop(['Airline'],axis=1,inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\2744902640.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   t_data['dep_hour'] = pd.to_datetime(t_data['Dep_Time'].astype(str)).dt.hour
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\2744902640.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   t_data['dep_min'] = pd.to_datetime(t_data['Dep_Time'].astype(str)).dt.minute
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\2744902640.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   t_data['arr_hour'] = pd.to_datetime(t_data['Arrival_Time'].astype(str)).dt.hour
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\2744902640.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   t_data['arr_min'] = pd.to_datetime(t_data['Arrival_Time'].astype(str)).dt.minute
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\2744902640.py:7: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   t_data['Journey_Day'] = pd.to_datetime(t_data['Date_of_Journey']).dt.day
# C:\Users\Admin\AppData\Local\Temp\ipykernel_22520\2744902640.py:8: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   t_data['Journey_Month'] = pd.to_datetime(t_data['Date_of_Journey']).dt.month

# %%
t_data.columns
# Out:
# Index(['Route', 'Total_Stops', 'Additional_Info', 'Price', 'dep_hour',
#        'dep_min', 'arr_hour', 'arr_min', 'Journey_Day', 'Journey_Month',
#        'Duration_hours', 'Duration_mins', 'Source_Chennai', 'Source_Delhi',
#        'Source_Kolkata', 'Source_Mumbai', 'Destination_Cochin',
#        'Destination_Delhi', 'Destination_Hyderabad', 'Destination_Kolkata',
#        'Destination_New Delhi', 'Air India', 'GoAir', 'IndiGo', 'Jet Airways',
#        'Jet Airways Business', 'Multiple carriers', 'SpiceJet', 'Vistara'],
#       dtype='object')

# %%
X_unseen = t_data[['Total_Stops', 'dep_hour',
       'dep_min', 'arr_hour', 'arr_min', 'Journey_Day', 'Journey_Month',
       'Duration_hours', 'Duration_mins', 'Source_Chennai', 'Source_Delhi',
       'Source_Kolkata', 'Source_Mumbai', 'Destination_Cochin',
       'Destination_Delhi', 'Destination_Hyderabad', 'Destination_Kolkata',
       'Destination_New Delhi', 'Air India', 'GoAir', 'IndiGo', 'Jet Airways',
       'SpiceJet', 'Vistara']].values
len(X_unseen)
# Out:
# 682

# %%
X_unseen.shape
# Out:
# (682, 24)

# %%
X.columns
# Out:
# Index(['stops', 'dep_hour', 'dep_min', 'arr_hour', 'arr_min', 'Journey_Day',
#        'Journey_Month', 'Duration_hours', 'Duration_mins',
#        'departure_loc_Chennai', 'departure_loc_Delhi', 'departure_loc_Mumbai',
#        'arrival_loc_Delhi', 'arrival_loc_Hyderabad', 'arrival_loc_Kolkata',
#        'arrival_loc_Mumbai', 'AirAsia', 'AkasaAir', 'AllianceAir', 'GO FIRST',
#        'Indigo', 'SpiceJet', 'StarAir', 'Vistara'],
#       dtype='object')

# %%
y_unseen = t_data.iloc[:,3]
y_unseen
# Out:
# 0      12898
# 1      10851
# 2       5704
# 3      11598
# 4       9149
#        ...
# 677     4107
# 678     4145
# 679     7229
# 680    12648
# 681    11753
# Name: Price, Length: 682, dtype: int64

# %%
t_data.drop(['Additional_Info','Route'], axis=1, inplace=True)

# %%
y_unseen.shape
# Out:
# (682,)

# %%
X.columns.shape
# Out:
# (24,)

# %%
y_pred = model_random_forest.predict(X_unseen)
# Out:
# C:\Users\Admin\anaconda3\envs\RP_Env\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
y_pred.shape
# Out:
# (682,)

# %%
metrics(y_unseen, y_pred)
# Out:
# RMSE: 5204.866964094235
# R_Squared_Value: -0.12932910507195383

# %%
accuracy(y_unseen, y_pred)
# Out:
# 57.28488106883534
